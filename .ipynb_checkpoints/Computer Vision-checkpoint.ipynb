# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read image and display

# %%
path_to_image = 'c:/Users/siddhant.dash/Downloads/klaus_hargreaves.jpg'
img = cv2.imread(path_to_image)

cv2.imshow('Frame_name',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Write image

# %%
path_to_image = 'c:/Users/siddhant.dash/Downloads/klaus_hargreaves.jpg'
img = cv2.imread(path_to_image)

cv2.imwrite('c:/Users/siddhant.dash/Downloads/klaus.jpg',img)
# Out:
# True

# %% [markdown]
# Atomic Info of an image

# %%
img.shape
# Out:
# (200, 200)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img)
# Out:
# [[ 84  84  84 ...  66  64  64]
#  [ 84  84  83 ...  64  61  61]
#  [ 84  84  83 ...  66  62  61]
#  ...
#  [ 34  35  35 ... 217 220 222]
#  [ 36  37  36 ... 216 217 219]
#  [ 36  37  37 ... 204 206 208]]

# %%
cv2.imshow('Cropped',img[0:120,60:150])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Drawing/writing on image

# %%
img1 = cv2.putText(img.copy(),'Klaus',(30,150),cv2.FONT_HERSHEY_SIMPLEX,1,(200,100,0),2,cv2.LINE_AA)
cv2.imshow('1',img1)
img2 = cv2.rectangle(img.copy(),(60,0),(150,120),(0,0,255),2)
cv2.imshow('2',img2)
img3 = cv2.circle(img.copy(),(80,80),30,(0,255,255),2)
cv2.imshow('3',img3)
img4 = cv2.line(img.copy(),(60,0),(150,120),(0,0,0),2)
cv2.imshow('4',img4)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Thresholding

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow('gray',gray)

val1,th1 = cv2.threshold(gray,125,255,cv2.THRESH_BINARY)
cv2.imshow('t1',th1)

val2,th2 = cv2.threshold(gray,125,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
cv2.imshow('t2',th2)

th3 = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,155,1)
cv2.imshow('t3',th3)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Image Arithmetics

# %%
img1 = cv2.imread('c:/Users/siddhant.dash/Downloads/left.jpg',)
img2 = cv2.imread('c:/Users/siddhant.dash/Downloads/up.jpg',)
img3 = cv2.imread('c:/Users/siddhant.dash/Downloads/among_us.png',)

# %%
plt.imshow(img3)

# %%
cv2.imshow('+150',img2+150)
cv2.imshow('-250',img1-250)
cv2.imshow('x10',img2*10)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('+100',cv2.add(100,img1))
cv2.imshow('-50',cv2.subtract(100,img1))
cv2.imshow('*5',cv2.multiply(img1,5))

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('+',img1+img2)
cv2.imshow('-',img1-img2)
cv2.imshow('*',img1*img2)
cv2.imshow('add',cv2.add(img1,img2))
cv2.imshow('sub',cv2.subtract(img1,img2))
cv2.imshow('mul',cv2.multiply(img1,blank))

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-ef2dbb7bb822> in <module>
#       4 cv2.imshow('add',cv2.add(img1,img2))
#       5 cv2.imshow('sub',cv2.subtract(img1,img2))
# ----> 6 cv2.imshow('mul',cv2.multiply(img1,blank))
#       7
#       8 cv2.waitKey(0)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-9d_dfo3_\opencv\modules\core\src\arithm.cpp:693: error: (-5:Bad argument) When the input arrays in add/subtract/multiply/divide functions have different types, the output array type must be explicitly specified in function 'cv::arithm_op'

# %%
cv2.imshow('wadd',cv2.addWeighted(img1,0.6,img2,0.4,0))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('not',cv2.bitwise_not(img1))
cv2.imshow('and',cv2.bitwise_and(img1,img2))
cv2.imshow('or',cv2.bitwise_or(img1,img2))
cv2.imshow('xor',cv2.bitwise_xor(img1,img2))

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('c:/Users/siddhant.dash/Downloads/cleft.jpg')

# %%
img3.shape
# Out:
# (882, 1572, 3)

# %%
rows,cols,channel = img2.shape
roi = img3[300:300+rows,500:500+cols]

img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
_ , mask = cv2.threshold(img2gray,200,255,cv2.THRESH_BINARY)

mask_inv = cv2.bitwise_not(mask)
#cv2.imshow('mask',mask)

img3_bg = cv2.bitwise_and(roi,roi,mask=mask)
img2_fg = cv2.bitwise_and(img2,img2,mask=mask_inv)

final = cv2.add(img3_bg,img2_fg)
img3[0:rows,0:cols] = final

cv2.imshow('result',img3)

cv2.waitKey(0)
cv2.destroyAllWindows()
